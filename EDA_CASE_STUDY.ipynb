# %% [markdown]
# <a href="https://colab.research.google.com/github/ramandeepp1403/EDA_CASE_STUDY/blob/main/EDA_CASE_STUDY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Case Study -EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/commodity_prices.csv')

# %%
df
# Out:
#      Unnamed: 0        date  oil_brent  oil_dubai  coffee_arabica  \
# 0             1  1960-01-01       1.63       1.63        0.940900
# 1             2  1960-02-01       1.63       1.63        0.946900
# 2             3  1960-03-01       1.63       1.63        0.928100
# 3             4  1960-04-01       1.63       1.63        0.930300
# 4             5  1960-05-01       1.63       1.63        0.920000
# ..          ...         ...        ...        ...             ...
# 751         752  2022-08-01      98.60      97.75        5.917861
# 752         753  2022-09-01      90.16      90.63        5.897138
# 753         754  2022-10-01      93.13      90.59        5.292852
# 754         755  2022-11-01      91.07      86.28        4.715462
# 755         756  2022-12-01      80.90      76.78        4.629482
#
#      coffee_robustas  tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  \
# 0           0.696864     0.930301     1.121401     1.037400  0.122356
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'oil_brent', 'oil_dubai', 'coffee_arabica',
#        'coffee_robustas', 'tea_columbo', 'tea_kolkata', 'tea_mombasa',
#        'sugar_eu', 'sugar_us', 'sugar_world'],
#       dtype='object')

# %%
# Remove the extra column

df = df.drop(columns = ['Unnamed: 0'])

# %%
df
# Out:
#            date  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 0    1960-01-01       1.63       1.63        0.940900         0.696864
# 1    1960-02-01       1.63       1.63        0.946900         0.688707
# 2    1960-03-01       1.63       1.63        0.928100         0.688707
# 3    1960-04-01       1.63       1.63        0.930300         0.684519
# 4    1960-05-01       1.63       1.63        0.920000         0.690692
# ..          ...        ...        ...             ...              ...
# 751  2022-08-01      98.60      97.75        5.917861         2.417366
# 752  2022-09-01      90.16      90.63        5.897138         2.455065
# 753  2022-10-01      93.13      90.59        5.292852         2.270979
# 754  2022-11-01      91.07      86.28        4.715462         2.041258
# 755  2022-12-01      80.90      76.78        4.629482         2.045446
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             756 non-null    object
#  1   oil_brent        756 non-null    float64
#  2   oil_dubai        756 non-null    float64
#  3   coffee_arabica   756 non-null    float64
#  4   coffee_robustas  756 non-null    float64
#  5   tea_columbo      756 non-null    float64
#  6   tea_kolkata      756 non-null    float64
#  7   tea_mombasa      756 non-null    float64
#  8   sugar_eu         756 non-null    float64
#  9   sugar_us         756 non-null    float64
#  10  sugar_world      756 non-null    float64
# dtypes: float64(10), object(1)
# memory usage: 65.1+ KB

# %%
# changing the datatype of the date column into proper format

df['date'] = pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             756 non-null    datetime64[ns]
#  1   oil_brent        756 non-null    float64
#  2   oil_dubai        756 non-null    float64
#  3   coffee_arabica   756 non-null    float64
#  4   coffee_robustas  756 non-null    float64
#  5   tea_columbo      756 non-null    float64
#  6   tea_kolkata      756 non-null    float64
#  7   tea_mombasa      756 non-null    float64
#  8   sugar_eu         756 non-null    float64
#  9   sugar_us         756 non-null    float64
#  10  sugar_world      756 non-null    float64
# dtypes: datetime64[ns](1), float64(10)
# memory usage: 65.1 KB

# %%
df
# Out:
#           date  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 0   1960-01-01       1.63       1.63        0.940900         0.696864
# 1   1960-02-01       1.63       1.63        0.946900         0.688707
# 2   1960-03-01       1.63       1.63        0.928100         0.688707
# 3   1960-04-01       1.63       1.63        0.930300         0.684519
# 4   1960-05-01       1.63       1.63        0.920000         0.690692
# ..         ...        ...        ...             ...              ...
# 751 2022-08-01      98.60      97.75        5.917861         2.417366
# 752 2022-09-01      90.16      90.63        5.897138         2.455065
# 753 2022-10-01      93.13      90.59        5.292852         2.270979
# 754 2022-11-01      91.07      86.28        4.715462         2.041258
# 755 2022-12-01      80.90      76.78        4.629482         2.045446
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world
# ...

# %%
# Data cleaning

# %%
df.isnull().sum()
# Out:
# date               0
# oil_brent          0
# oil_dubai          0
# coffee_arabica     0
# coffee_robustas    0
# tea_columbo        0
# tea_kolkata        0
# tea_mombasa        0
# sugar_eu           0
# sugar_us           0
# sugar_world        0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
for i in df.columns:
  if df[i].dtype == 'int64' or df[i].dtype == 'float64':
    sns.boxplot(df[i])
    plt.title(i)
    plt.show()

# %%
#  remove the records which are outliers


for i in df.columns:
   if df[i].dtype == 'int64' or df[i].dtype == 'float64':
     Q1 = df[i].quantile(0.25)
     Q3 = df[i].quantile(0.75)
     IQR = Q3 - Q1
     upper_fence = Q3  + (1.5 * IQR)
     lower_fence = Q1 - (1.5 * IQR)
     df = df[(df[i] >= lower_fence) & (df[i] <= upper_fence)]

# %%
for i in df.columns:
  if df[i].dtype == 'int64' or df[i].dtype == 'float64':
    sns.boxplot(df[i])
    plt.title(i)
    plt.show()

# %% [markdown]
# # Data Analysis

# %% [markdown]
# # Maximum and minimum price of Robusta coffee from 1960 to 2022 ?
#
# #  Print the data between the 1960 to 1980

# %%
df.columns
# Out:
# Index(['date', 'oil_brent', 'oil_dubai', 'coffee_arabica', 'coffee_robustas',
#        'tea_columbo', 'tea_kolkata', 'tea_mombasa', 'sugar_eu', 'sugar_us',
#        'sugar_world'],
#       dtype='object')

# %%
max_price = df['coffee_robustas'].max()

# %%
max_price
# Out:
# 4.1621

# %%
min_price = df['coffee_robustas'].min()

print(min_price)
# Out:
# 0.4872098

# %%
new_data = df[(df['date'] >= '1960-01-01') & (df['date'] <= '1980-12-01')]

# %%
new_data
# Out:
#           date  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 0   1960-01-01   1.630000       1.63          0.9409         0.696864
# 1   1960-02-01   1.630000       1.63          0.9469         0.688707
# 2   1960-03-01   1.630000       1.63          0.9281         0.688707
# 3   1960-04-01   1.630000       1.63          0.9303         0.684519
# 4   1960-05-01   1.630000       1.63          0.9200         0.690692
# ..         ...        ...        ...             ...              ...
# 238 1979-11-01  42.000000      39.50          4.5574         3.909000
# 239 1979-12-01  40.500000      39.00          4.2831         3.902000
# 240 1980-01-01  40.000000      38.00          3.8078         3.571300
# 242 1980-03-01  38.250000      35.75          4.1173         3.722500
# 243 1980-04-01  38.150002      35.00          4.0528         3.646400
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world
# ...

# %%
df['date'].head(50)
# Out:
# 0    1960-01-01
# 1    1960-02-01
# 2    1960-03-01
# 3    1960-04-01
# 4    1960-05-01
# 5    1960-06-01
# 6    1960-07-01
# 7    1960-08-01
# 8    1960-09-01
# 9    1960-10-01
# 10   1960-11-01
# 11   1960-12-01
# 12   1961-01-01
# 13   1961-02-01
# 14   1961-03-01
# 15   1961-04-01
# 16   1961-05-01
# 17   1961-06-01
# 18   1961-07-01
# 19   1961-08-01
# 20   1961-09-01
# 21   1961-10-01
# 22   1961-11-01
# 23   1961-12-01
# 24   1962-01-01
# 25   1962-02-01
# 26   1962-03-01
# 27   1962-04-01
# 28   1962-05-01
# 29   1962-06-01
# 30   1962-07-01
# 31   1962-08-01
# 32   1962-09-01
# 33   1962-10-01
# 34   1962-11-01
# 35   1962-12-01
# 36   1963-01-01
# 37   1963-02-01
# 38   1963-03-01
# 39   1963-04-01
# 40   1963-05-01
# 41   1963-06-01
# 42   1963-07-01
# 43   1963-08-01
# 44   1963-09-01
# 45   1963-10-01
# 46   1963-11-01
# 47   1963-12-01
# 48   1964-01-01
# 49   1964-02-01
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# #  Compare price trends of Arabica vs Robusta coffee. Which is more volatile?

# %%
df.columns
# Out:
# Index(['date', 'oil_brent', 'oil_dubai', 'coffee_arabica', 'coffee_robustas',
#        'tea_columbo', 'tea_kolkata', 'tea_mombasa', 'sugar_eu', 'sugar_us',
#        'sugar_world'],
#       dtype='object')

# %%
df[['date','coffee_arabica','coffee_robustas']].set_index('date').plot(figsize = (12,5), color = ['saddlebrown', 'darkgreen'])
plt.title("Arabica vs Robustas Coffee")
plt.show()

# %%
df['coffee_arabica'].std()
# Out:
# 1.0989846773235519

# %%
df['coffee_robustas'].std()
# Out:
# 0.8688249704924804

# %% [markdown]
# # Plot the trend of sugar_world prices over time.

# %%
df
# Out:
#           date  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 0   1960-01-01       1.63       1.63        0.940900         0.696864
# 1   1960-02-01       1.63       1.63        0.946900         0.688707
# 2   1960-03-01       1.63       1.63        0.928100         0.688707
# 3   1960-04-01       1.63       1.63        0.930300         0.684519
# 4   1960-05-01       1.63       1.63        0.920000         0.690692
# ..         ...        ...        ...             ...              ...
# 734 2021-03-01      65.19      63.95        3.682818         1.628332
# 735 2021-04-01      64.77      62.37        3.718092         1.641560
# 736 2021-05-01      68.04      65.98        4.110734         1.756641
# 737 2021-06-01      73.07      70.96        4.243012         1.870179
# 739 2021-08-01      70.02      68.85        4.767270         2.098357
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world
# ...

# %%
plt.figure(figsize = (12,4))
sns.lineplot(x = 'date', y = 'sugar_world', data = df)
plt.title("Global Sugar Price Over time")
# Out:
# Text(0.5, 1.0, 'Global Sugar Price Over time')

# %% [markdown]
# # Which commodity has the highest average price over the full dataset?

# %%
df.columns
# Out:
# Index(['date', 'oil_brent', 'oil_dubai', 'coffee_arabica', 'coffee_robustas',
#        'tea_columbo', 'tea_kolkata', 'tea_mombasa', 'sugar_eu', 'sugar_us',
#        'sugar_world'],
#       dtype='object')

# %%
avg_prices = df[['oil_brent', 'oil_dubai', 'coffee_arabica', 'coffee_robustas',
       'tea_columbo', 'tea_kolkata', 'tea_mombasa', 'sugar_eu', 'sugar_us',
       'sugar_world']].mean().sort_values(ascending = False)

# %%
avg_prices
# Out:
# oil_brent          20.999878
# oil_dubai          19.715082
# coffee_arabica      2.178528
# tea_kolkata         1.671906
# coffee_robustas     1.538308
# tea_mombasa         1.452477
# tea_columbo         1.414661
# sugar_eu            0.399039
# sugar_us            0.376091
# sugar_world         0.187043
# dtype: float64

# %%
avg_prices.plot(kind = 'bar', color = 'skyblue', figsize = (10,5))
plt.show()

# %% [markdown]
# # Create a new column indicating whether tea_columbo price was above average.

# %%
mean_columbo = df['tea_columbo'].mean()

# %%
mean_columbo
# Out:
# np.float64(1.4146611358563541)

# %%
df['columbo_above_avg'] = df['tea_columbo'] > mean_columbo

# %%
df['columbo_above_avg']
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 734     True
# 735     True
# 736     True
# 737     True
# 739     True
# Name: columbo_above_avg, Length: 576, dtype: bool

# %%
df['columbo_above_avg'] = np.where(df['tea_columbo'] > mean_columbo, 'Above Avg','Below Avg')

# %%
df['columbo_above_avg']
# Out:
# 0      Below Avg
# 1      Below Avg
# 2      Below Avg
# 3      Below Avg
# 4      Below Avg
#          ...
# 734    Above Avg
# 735    Above Avg
# 736    Above Avg
# 737    Above Avg
# 739    Above Avg
# Name: columbo_above_avg, Length: 576, dtype: object

# %% [markdown]
# # In which year did all tea prices (3 regions) exceed their long-term averages?

# %%
df.columns
# Out:
# Index(['date', 'oil_brent', 'oil_dubai', 'coffee_arabica', 'coffee_robustas',
#        'tea_columbo', 'tea_kolkata', 'tea_mombasa', 'sugar_eu', 'sugar_us',
#        'sugar_world', 'columbo_above_avg'],
#       dtype='object')

# %%
means = df[['tea_columbo', 'tea_kolkata', 'tea_mombasa']].mean()

# %%
means
# Out:
# tea_columbo    1.414661
# tea_kolkata    1.671906
# tea_mombasa    1.452477
# dtype: float64

# %%
filtered = df[
    (df['tea_columbo'] > means['tea_columbo'])&
    (df['tea_kolkata'] > means['tea_kolkata'])&
    (df['tea_mombasa'] > means['tea_mombasa'])
]

# %%
filtered
# Out:
#           date  oil_brent  oil_dubai  coffee_arabica  coffee_robustas  \
# 272 1982-09-01  34.250000  33.049999        3.004200         2.409200
# 277 1983-02-01  29.100000  29.000000        2.798300         2.684600
# 278 1983-03-01  28.200001  28.100000        2.756700         2.672700
# 279 1983-04-01  29.750000  28.700001        2.750500         2.672700
# 280 1983-05-01  29.600000  28.500000        2.832300         2.715200
# ..         ...        ...        ...             ...              ...
# 734 2021-03-01  65.190000  63.950000        3.682818         1.628332
# 735 2021-04-01  64.770000  62.370000        3.718092         1.641560
# 736 2021-05-01  68.040000  65.980000        4.110734         1.756641
# 737 2021-06-01  73.070000  70.960000        4.243012         1.870179
# 739 2021-08-01  70.020000  68.850000        4.767270         2.098357
#
#      tea_columbo  tea_kolkata  tea_mombasa  sugar_eu  sugar_us  sugar_world  \
# ...

# %%
filtered['date'].dt.year
# Out:
# 272    1982
# 277    1983
# 278    1983
# 279    1983
# 280    1983
#        ...
# 734    2021
# 735    2021
# 736    2021
# 737    2021
# 739    2021
# Name: date, Length: 156, dtype: int32

# %%
filtered['date'].dt.year.value_counts().sort_index()
# Out:
# date
# 1982     1
# 1983    11
# 1984     6
# 1985     4
# 1986     1
# 1989     3
# 1990     8
# 1991     5
# 1992     2
# 1993     5
# 1997     9
# 1998    11
# 1999    10
# 2000     7
# 2001     4
# 2002     1
# 2003     1
# 2004     8
# 2005     3
# 2006     8
# 2007     5
# 2008     3
# 2009     5
# 2014     1
# 2015     3
# 2016     7
# 2018     3
# 2019    11
# 2020     3
# 2021     7
# Name: count, dtype: int64

# %% [markdown]
# # Boxplot of sugar prices by region (eu, us, world).

# %%
sns.boxplot(data = df[['sugar_eu', 'sugar_us','sugar_world']])
plt.title("Sugar Price Distribution by Region")
plt.show()
